# %% [markdown]
# <a href="https://colab.research.google.com/github/raulval9/RentaVariable/blob/main/PreciosComponentesDeIndices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, pandas as pd
from io import StringIO
import yfinance as yf

# %%
api = 'https://en.wikipedia.org/w/api.php'
indice = 'SP500'
if indice == 'SP500':
  params = {
      'action': 'parse',
      'page': 'List_of_S&P_500_companies',
      'prop': 'text',
      'format': 'json'
  }
  headers = {'User-Agent': 'indice-tickers-tutorial/1.0'}
  r = requests.get(api, params=params, headers=headers)
  html = r.json()['parse']['text']['*']

  df = pd.read_html(StringIO(html))[0]
  tickers = df['Symbol'].astype(str).tolist()
elif indice == 'IPC':
  params = {
      'action': 'parse',
      'page': 'Índice_de_Precios_y_Cotizaciones',
 #     'section': '1',
      'prop': 'text',
      'format': 'json'
  }
  tickers = ['AC.MX', 'ALSEA.MX', 'AMXB.MX', 'ASURB.MX', 'BBAJIOO.MX', 'BIMBOA.MX', 'BOLSAA.MX', 'CEMEXCPO.MX', 'CHDRAUIB.MX', 'CUERVO.MX', 'GAPB.MX', 'GCARSOA1.MX', 'GCC.MX', 'GENTERA.MX', 'GMEXICOB.MX', 'GRUMAB.MX', 'KIMBERA.MX', 'LABB.MX', 'LACOMERUBC.MX', 'LIVEPOLC1.MX', 'MEGACPO.MX', 'OMAB.MX', 'ORBIA.MX', 'PINFRA.MX', 'Q.MX', 'RA.MX', 'TLEVISACPO.MX', 'VESTA.MX']

# %%
print(tickers)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'AON', 'APA', 'APO', 'AAPL', 'AMAT', 'APP', 'APTV', 'ACGL', 'ADM', 'ARES', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BAX', 'BDX', 'BRK.B', 'BBY', 'TECH', 'BIIB', 'BLK', 'BX', 'XYZ', 'BK', 'BA', 'BKNG', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'BXP', 'CHRW', 'CDNS', 'CPT', 'CPB', 'COF', 'CAH', 'CCL', 'CARR', 'CVNA', 'CAT', 'CBOE', 'CBRE', 'CDW', 'COR', 'CNC', 'CNP', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CIEN', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'COIN', 'CL', 'CMCSA', 'FIX', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CPAY', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CRH', 'CRWD', 'CCI', 'CSX', 'CMI
# ...

# %%
fecha_inicio = "2026-02-13"
fecha_fin = "2026-02-21"

df_indices = {}

for tick in tickers:
  try:
    info = yf.Ticker(tick)
    df = info.history(start=fecha_inicio, end=fecha_fin)
    df.index = df.index.strftime('%Y-%m-%d')
    df_indices[tick] = df["Close"]

  except Exception as e:
    print(f"Error descargando {tick}: {e}")

df_all_indices = pd.DataFrame(df_indices)
# Out:
# ERROR:yfinance:$BRK.B: possibly delisted; no timezone found
# Error descargando BRK.B: 'Index' object has no attribute 'strftime'
# ERROR:yfinance:$BF.B: possibly delisted; no price data found  (1d 2026-02-13 -> 2026-02-21)
# Error descargando BF.B: 'Index' object has no attribute 'strftime'

# %%
df_all_indices.to_excel('precios_'+indice+'_'+fecha_inicio+'_'+fecha_fin+'.xlsx')

# %% [markdown]
# <a href="https://colab.research.google.com/github/raulval9/RentaVariable/blob/main/AnalisisTickers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd

id = "TSLA"
tesla = yf.Ticker(id)
tesla.history(period = "max")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2025-09-12 00:00:00-04:00  370.940002  396.690002  370.239990  395.940002
# 2025-09-15 00:00:00-04:00  423.130005  425.700012  402.429993  410.040009
# 2025-09-16 00:00:00-04:00  414.500000  423.250000  411.429993  421.619995
# 2025-09-17 00:00:00-04:00  415.750000  428.309998  409.670013  425.859985
# 2025-09-18 00:00:00-04:00  428.869995  432.220001  416.559998  416.850006
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
tesla.balance_sheet
# Out:
#                                                     2024-12-31    2023-12-31  \
# Treasury Shares Number                                     NaN  0.000000e+00
# Ordinary Shares Number                            3.216000e+09  3.185000e+09
# Share Issued                                      3.216000e+09  3.185000e+09
# Total Debt                                        1.362300e+10  9.573000e+09
# Tangible Book Value                               7.144300e+10  6.201900e+10
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  3.656300e+10  2.909400e+10
# Other Short Term Investments                      2.042400e+10  1.269600e+10
# Cash And Cash Equivalents                         1.613900e+10  1.639800e+10
# Cash Equivalents                                  1.753000e+09  4.950000e+08
# Cash Financial                                    1.438600e+10  1.590300e+10
#
# ...

# %%
tesla.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          5   15    17     6           2
# 1    -1m          5   14    18     7           3
# 2    -2m          5   13    18     7           3
# 3    -3m          7   14    16     7           3
